# %%
import pandas as pd
import statsmodels.api as sm
import statsmodels.stats.api as sms

# %%
basic_eps = pd.read_csv('D:\Data\Basic EPS.csv' , sep=";")

# %%
print(basic_eps)
# Out:
#           Date Basic EPS
# 0   30.09.2021       NaN
# 1   30.06.2021      0,81
# 2   31.03.2021       0,7
# 3   31.12.2020      1,03
# 4   30.09.2020      1,04
# ..         ...       ...
# 62  31.03.2006      0,47
# 63  31.12.2005      0,14
# 64  30.09.2005      0,28
# 65  30.06.2005      0,11
# 66  31.03.2005      0,19
#
# [67 rows x 2 columns]

# %%
cashflow_fa = pd.read_csv('D:\Data\cash flow from financial activities.csv' , sep=";")

# %%
print(cashflow_fa)
# Out:
#           Date  Cash flow from financial activities
# 0   30.09.2021                                 -697
# 1   30.06.2021                                -1155
# 2   31.03.2021                                 -511
# 3   31.12.2020                                 -561
# 4   30.09.2020                                 -242
# ..         ...                                  ...
# 62  31.03.2006                                  -80
# 63  31.12.2005                                 -193
# 64  30.09.2005                                 -122
# 65  30.06.2005                                 -156
# 66  31.03.2005                                  509
#
# [67 rows x 2 columns]

# %%
share_price = pd.read_csv('D:\Data\Share_Price.csv' , sep=";")

# %%
pd.DataFrame({'date':pd.data_range('31.03.2005',periods 67)})
# Out:
#   Cell In[37], line 1
#     pd.DataFrame({'date':pd.data_range('31.03.2005',periods 67)})
#                                                     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
x0 = basic_eps
x1 = cashflow_fa
x = x0, x1
y = share_price

# %%
model = sm.OLS(y, x, hasconst=True)
results = model.fit()
results.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 model = sm.OLS(y, x, hasconst=True)
#       2 results = model.fit()
#       3 results.summary()
#
# File E:\env\lib\site-packages\statsmodels\regression\linear_model.py:906, in OLS.__init__(self, endog, exog, missing, hasconst, **kwargs)
#     903     msg = ("Weights are not supported in OLS and will be ignored"
#     904            "An exception will be raised in the next version.")
#     905     warnings.warn(msg, ValueWarning)
# --> 906 super(OLS, self).__init__(endog, exog, missing=missing,
#     907                           hasconst=hasconst, **kwargs)
#     908 if "weights" in self._init_keys:
#     909     self._init_keys.remove("weights")
#
# File E:\env\lib\site-packages\statsmodels\regression\linear_model.py:733, in WLS.__init__(self, endog, exog, weights, missing, hasconst, **kwargs)
# ...
